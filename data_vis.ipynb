# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
data_root = Path('data/low_freq')
mains1 = pd.read_csv(data_root.joinpath('house_1/channel_1.dat'), header=None, delimiter=' ', index_col=0)
mains2 = pd.read_csv(data_root.joinpath('house_1/channel_2.dat'), header=None, delimiter=' ', index_col=0)
kit1 = pd.read_csv(data_root.joinpath('house_1/channel_7.dat'),header=None, delimiter=' ', index_col=0)
kit2 = pd.read_csv(data_root.joinpath('house_1/channel_8.dat'),header=None, delimiter=' ', index_col=0)
dryer1 = pd.read_csv(data_root.joinpath('house_1/channel_19.dat'), header=None, delimiter=' ', index_col=0)
dryer2 = pd.read_csv(data_root.joinpath('house_1/channel_20.dat'), header=None, delimiter=' ', index_col=0)

# %%
plt.plot(mains1.iloc[:10000,1])

# %%
plt.plot(mains2.iloc[:10000,1])

# %%
plt.plot(kit1.iloc[:10000,1])

# %%
plt.plot(kit2.iloc[:10000,1])

# %%
plt.plot(dryer1.iloc[:10000,1])

# %%
plt.plot(dryer2.iloc[:10000,0].tolist())
dryer2.iloc[:10000,0].unique()
# Out:
# array([0. , 2.5])

# %%
plt.plot(kit1)
